# %% [markdown]
# # LLM 모델 (OpenAI 기준)
#
# ##  범용 LLM 생성: `init_chat_model`

# %%
from langchain.chat_models import init_chat_model
from IPython.display import Markdown

user_input = "명탐정 코난에서 에도가와 코난과 쿠도 신이치를 키와 나이를 포함해서 표로 비교 설명해줘"

chat_model = init_chat_model(
    model="openai:gpt-4o-mini",
    temperature=0.5,
    max_tokens=500,
)
response = chat_model.invoke(user_input)

Markdown(response.content)
# Out:
# 명탐정 코난에서 에도가와 코난과 쿠도 신이치는 동일한 인물로, 코난은 신이치가 어린아이의 모습으로 변한 캐릭터입니다. 아래는 두 캐릭터의 키와 나이를 포함한 비교 표입니다.
#
# | 캐릭터 이름      | 나이         | 키         | 설명                                      |
# |------------------|--------------|------------|------------------------------------------|
# | 에도가와 코난   | 7세 (어린이) | 약 140cm   | 신이치가 독약에 의해 어린아이의 모습으로 변한 상태. 탐정 역할을 수행. |
# | 쿠도 신이치      | 17세         | 약 178cm   | 천재 고등학생 탐정으로, 성인 모습. 코난의 원래 모습.          |
#
# 이 표를 통해 에도가와 코난과 쿠도 신이치의 나이와 키의 차이를 확인할 수 있습니다. 코난은 신이치의 어린 모습으로, 주로 어린아이의 시각에서 사건을 해결하는 역할을 합니다.

# %% [markdown]
# ## OpenAI 전용 LLM 생성: `ChatOpenAI`

# %%
from langchain_openai import ChatOpenAI

chat_openai = ChatOpenAI(
    model="gpt-4o-mini", 
    temperature=0.5,
    max_tokens=500
)

response = chat_openai.invoke(user_input)

Markdown(response.content)
